# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
import npy_data_readers as read_npy
import halo_readers as read_halo
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot.sightlines_contours('T1_Aug','DLA',snap_num=156)
# Out:
#  Redshift file for T1_Aug located
#
# Snapshot Number: 156
# Snapshot Redshift: 2.207925472383703
# /cosma/home/durham/dc-coll7/masters/plot_generation.py:1146: RuntimeWarning: divide by zero encountered in log10
#   adj_obj_imshows=[ax_sightlineconts[nh_masks.index(col_dens)][planes[plane]['index']].imshow(np.log10(loaded_data[plane]),extent=shifted_obj_extents[plane],vmin=vmin,vmax=vmax,cmap=dens_plot_info['cmap'],aspect='equal',zorder=0) for plane in planes]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plot.sightlines_contours('T1_Aug','DLA',snap_num=156)
#
# File ~/masters/plot_generation.py:1163, in sightlines_contours(halo, col_dens, **kwargs)
#    1159 norm=mpl.colors.BoundaryNorm(radii, radial_cmap.N)
#    1161 cbar_data=np.linspace(0, 10, 100).reshape(10, 10)
# ...
