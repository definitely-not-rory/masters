# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
from npy_data_readers import generate_units_file
from processing import get_extent
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
halo='T1_Aug'

data.get_mass_density_data(halo,redshift=1,all_plots=True)

#Testing github actually works now
# Out:
#  T1_Aug redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 164
# Snapshot True Redshift: 0.9972942257819404
# Redshift Difference: 0.270577421805962%
#
# Snapshot 164 Gas raw data located
#
# Snapshot 164 DM raw data located
#
# Snapshot 164 Stars raw data located
# Gas Relative Positions Loaded
# DM Relative Positions Loaded
# Stars Relative Positions Loaded
# Gas Radial Positions Loaded
# DM Radial Positions Loaded
# Stars Radial Positions Loaded
#
# gas projected density file loaded
#
# dm projected density file loaded
#
# stars projected density file loaded
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 164
# Snapshot Redshift: 0.9972942257819404
