# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
import npy_data_readers as read_npy
import halo_readers as read_halo
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start_z=read_halo.get_snap_num('halo8',4)[0]
end_z=read_halo.get_snap_num('halo8',1)[0]

print(f'{start_z},{end_z},diff={int(end_z)-int(start_z)}')
# Out:
#  halo8 redshift file imported
#
# --- Target Redshift: 4 ---
# Snapshot Number Selected: 070
# Snapshot True Redshift: 3.9842720405101524
# Redshift Difference: 0.3931989872461905%
#
#  halo8 redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 107
# Snapshot True Redshift: 0.9597955062521444
# Redshift Difference: 4.020449374785562%
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       1 start_z=read_halo.get_snap_num('halo8',4)[0]
#       2 end_z=read_halo.get_snap_num('halo8',1)[0]
# ----> 4 print(f'{start_z},{end_z},diff={end_z-start_z}')
#
# TypeError: unsupported operand type(s) for -: 'numpy.str_' and 'numpy.str_'
