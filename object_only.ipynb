# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
import npy_data_readers as read_npy
import halo_readers as read_halo

# %%
halos='T1_Aug','T4_Aug','halo8'

for halo in halos:
    plot.plot_stellar_masses(halo)
# Out:
# Halo Directory Not Present
# Created directory for T1_Aug
#
# Halo Directory Not Present
# Created stellar mass directory for T1_Aug
#
#  T1_Aug redshift file imported
#
# --- Target Redshift: 4 ---
# Snapshot Number Selected: 152
# Snapshot True Redshift: 4.0079451114652676
# Redshift Difference: 0.19862778663168879%
#
#  T1_Aug redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 164
# Snapshot True Redshift: 0.9972942257819404
# Redshift Difference: 0.270577421805962%
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 152
# Snapshot Redshift: 4.0079451114652676
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 153
# Snapshot Redshift: 3.344350865135782
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 154
# Snapshot Redshift: 2.859040507202043
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 156
# Snapshot Redshift: 2.207925472383703
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 157
# Snapshot Redshift: 1.9596563814681223
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 158
# Snapshot Redshift: 1.769693939642695
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 159
# Snapshot Redshift: 1.5919240379818054
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 160
# Snapshot Redshift: 1.4486595247532112
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 161
# Snapshot Redshift: 1.3133137315371863
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 162
# Snapshot Redshift: 1.1958288722076
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 163
# Snapshot Redshift: 1.0942101917585805
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 164
# Snapshot Redshift: 0.9972942257819404
#
# Halo Directory Not Present
# Created directory for T4_Aug
#
# Halo Directory Not Present
# Created stellar mass directory for T4_Aug
#
#  T4_Aug redshift file imported
#
# --- Target Redshift: 4 ---
# Snapshot Number Selected: 152
# Snapshot True Redshift: 4.0079451114652676
# Redshift Difference: 0.19862778663168879%
#
#  T4_Aug redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 164
# Snapshot True Redshift: 0.9972942257819404
# Redshift Difference: 0.270577421805962%
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 152
# Snapshot Redshift: 4.0079451114652676
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 153
# Snapshot Redshift: 3.344350865135782
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 154
# Snapshot Redshift: 2.859040507202043
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 156
# Snapshot Redshift: 2.207925472383703
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 157
# Snapshot Redshift: 1.9596563814681223
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 158
# Snapshot Redshift: 1.769693939642695
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 159
# Snapshot Redshift: 1.5919240379818054
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 160
# Snapshot Redshift: 1.4486595247532112
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 161
# Snapshot Redshift: 1.3133137315371863
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 162
# Snapshot Redshift: 1.1958288722076
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 163
# Snapshot Redshift: 1.0942101917585805
#
#  Redshift file for T4_Aug located
#
# Snapshot Number: 164
# Snapshot Redshift: 0.9972942257819404
#
# Directory for halo8 located
#
# Directory for halo8 located
#
#  halo8 redshift file imported
#
# --- Target Redshift: 4 ---
# Snapshot Number Selected: 070
# Snapshot True Redshift: 3.9842720405101524
# Redshift Difference: 0.3931989872461905%
#
#  halo8 redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 107
# Snapshot True Redshift: 0.9597955062521444
# Redshift Difference: 4.020449374785562%
#
#  Redshift file for halo8 located
#
# Snapshot Number: 070
# Snapshot Redshift: 3.9842720405101524
#
#  Redshift file for halo8 located
#
# Snapshot Number: 071
# Snapshot Redshift: 3.9372610847275835
#
#  Redshift file for halo8 located
#
# Snapshot Number: 072
# Snapshot Redshift: 3.91392214442748
#
#  Redshift file for halo8 located
#
# Snapshot Number: 073
# Snapshot Redshift: 3.8675747190114658
#
#  Redshift file for halo8 located
#
# Snapshot Number: 074
# Snapshot Redshift: 3.8216644360204963
#
#  Redshift file for halo8 located
#
# Snapshot Number: 075
# Snapshot Redshift: 3.7761871723884433
#
#  Redshift file for halo8 located
#
# Snapshot Number: 076
# Snapshot Redshift: 3.731138843937364
#
#  Redshift file for halo8 located
#
# Snapshot Number: 077
# Snapshot Redshift: 3.686515405010711
#
#  Redshift file for halo8 located
#
# Snapshot Number: 078
# Snapshot Redshift: 3.642312848109996
#
#  Redshift file for halo8 located
#
# Snapshot Number: 079
# Snapshot Redshift: 3.6203681584212974
#
#  Redshift file for halo8 located
#
# Snapshot Number: 080
# Snapshot Redshift: 3.5767894930857462
#
#  Redshift file for halo8 located
#
# Snapshot Number: 081
# Snapshot Redshift: 3.5336218556179553
#
#  Redshift file for halo8 located
#
# Snapshot Number: 082
# Snapshot Redshift: 3.4908613692606485
#
#  Redshift file for halo8 located
#
# Snapshot Number: 083
# Snapshot Redshift: 3.469632606269477
#
#  Redshift file for halo8 located
#
# Snapshot Number: 084
# Snapshot Redshift: 3.427475657549609
#
#  Redshift file for halo8 located
#
# Snapshot Number: 085
# Snapshot Redshift: 3.3857163272655084
#
#  Redshift file for halo8 located
#
# Snapshot Number: 086
# Snapshot Redshift: 3.364984595688288
#
#  Redshift file for halo8 located
#
# Snapshot Number: 087
# Snapshot Redshift: 3.323814672347085
#
#  Redshift file for halo8 located
#
# Snapshot Number: 088
# Snapshot Redshift: 3.303375556251164
#
#  Redshift file for halo8 located
#
# Snapshot Number: 089
# Snapshot Redshift: 3.262786720740894
#
#  Redshift file for halo8 located
#
# Snapshot Number: 090
# Snapshot Redshift: 3.2426360900409703
#
#  Redshift file for halo8 located
#
# Snapshot Number: 091
# Snapshot Redshift: 3.2026201406687473
#
#  Redshift file for halo8 located
#
# Snapshot Number: 092
# Snapshot Redshift: 3.1629816161263147
#
#  Redshift file for halo8 located
#
# Snapshot Number: 093
# Snapshot Redshift: 3.1433027744078297
#
#  Redshift file for halo8 located
#
# Snapshot Number: 094
# Snapshot Redshift: 3.104223722955905
#
#  Redshift file for halo8 located
#
# Snapshot Number: 095
# Snapshot Redshift: 3.084822635834013
#
#  Redshift file for halo8 located
#
# Snapshot Number: 096
# Snapshot Redshift: 3.046295160858313
#
#  Redshift file for halo8 located
#
# Snapshot Number: 097
# Snapshot Redshift: 3.0271679079998446
#
#  Redshift file for halo8 located
#
# Snapshot Number: 098
# Snapshot Redshift: 3.008131071630377
#
#  Redshift file for halo8 located
#
# Snapshot Number: 099
# Snapshot Redshift: 2.543549770799998
#
#  Redshift file for halo8 located
#
# Snapshot Number: 100
# Snapshot Redshift: 2.1776687686343283
#
#  Redshift file for halo8 located
#
# Snapshot Number: 101
# Snapshot Redshift: 1.9040895435327672
#
#  Redshift file for halo8 located
#
# Snapshot Number: 102
# Snapshot Redshift: 1.6793350481066067
#
#  Redshift file for halo8 located
#
# Snapshot Number: 103
# Snapshot Redshift: 1.4955121664955557
#
#  Redshift file for halo8 located
#
# Snapshot Number: 104
# Snapshot Redshift: 1.3243009408353608
#
#  Redshift file for halo8 located
#
# Snapshot Number: 105
# Snapshot Redshift: 1.1854489635744057
#
#  Redshift file for halo8 located
#
# Snapshot Number: 106
# Snapshot Redshift: 1.064651718993035
#
#  Redshift file for halo8 located
#
# Snapshot Number: 107
# Snapshot Redshift: 0.9597955062521444
