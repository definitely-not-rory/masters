# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
import npy_data_readers as read_npy
import halo_readers as read_halo

# %%
halos=['T1_Aug','halo8','T4_Aug']
# Out:
#  T1_Aug redshift file imported
#
# --- Target Redshift: 3 ---
# Snapshot Number Selected: 154
# Snapshot True Redshift: 2.859040507202043
# Redshift Difference: 4.6986497599319055%
# /cosma/home/durham/dc-coll7/masters/plot_generation.py:608: RuntimeWarning: divide by zero encountered in log10
#   imshows=[ax_gashist[planes[plane]['index']].imshow(np.log10(loaded_data[plane]),extent=plot_extents[plane],vmin=vmin,vmax=vmax,cmap=dens_plot_info['cmap'],aspect='equal') for plane in planes]
