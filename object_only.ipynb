# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
from npy_data_readers import read_subfind_params
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
read_subfind_params('T1_Aug',redshift=1)
# Out:
#  T1_Aug redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 164
# Snapshot True Redshift: 0.9972942257819404
# Redshift Difference: 0.270577421805962%
# {'redshift': 0.9972942257819404, 'halo_pos': <Quantity [26.03068071, 25.3216272 , 27.15791359] Mpc>, 'halo_mass': <Quantity 2.52826014e+09 solMass>, 'halo_r200': <Quantity 0.02010888 Mpc>}

# %%
halo='T1_Aug'

data.get_mass_density_data(halo,redshift=1)
# Out:
#  T1_Aug redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 164
# Snapshot True Redshift: 0.9972942257819404
# Redshift Difference: 0.270577421805962%
#
# Snapshot 164 Gas raw data located
#
# Snapshot 164 DM raw data located
#
# Snapshot 164 Stars raw data located
# dict_keys(['gas', 'dm', 'stars'])
# [[26.03067893 25.32162633 27.15791358]
#  [26.03067891 25.32162634 27.15791358]
#  [26.03067975 25.32162584 27.15791357]
#  ...
#  [26.02819604 25.32001185 27.1585437 ]
#  [26.03945147 25.32908209 27.15471796]
#  [26.04569645 25.32356839 27.14592068]] Mpc
# [[26.0306866  25.32162416 27.15792225]
#  [26.0306898  25.32162611 27.15792234]
#  [26.03067892 25.32162037 27.15792097]
#  ...
#  [26.02942557 25.33092516 27.17091007]
#  [26.04780964 25.32342366 27.15227179]
#  [26.02786417 25.33595784 27.16328052]] Mpc
# [[26.03067931 25.3216277  27.15791351]
#  [26.03068012 25.32162766 27.15791408]
#  [26.03068043 25.32162689 27.15791256]
#  ...
#  [26.04024489 25.32538233 27.15197953]
#  [26.03895192 25.32566424 27.15232446]
#  [26.03995192 25.32552787 27.15284483]] Mpc
