# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
from npy_data_readers import generate_units_file
from processing import get_extent
from run_full_dataset import run_halo
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
run_halo('T1_Aug',512,4,1)
# Out:
#  T1_Aug redshift file imported
#
# --- Target Redshift: 4 ---
# Snapshot Number Selected: 152
# Snapshot True Redshift: 4.0079451114652676
# Redshift Difference: 0.19862778663168879%
#
#  T1_Aug redshift file imported
#
# --- Target Redshift: 1 ---
# Snapshot Number Selected: 164
# Snapshot True Redshift: 0.9972942257819404
# Redshift Difference: 0.270577421805962%
# [152 153 154 155 156 157 158 159 160 161 162 163 164]

# %%
halo='T1_Aug'


data.get_gas_only_data(halo,snap_num=165,all_plots=True)
# Out:
# Directory for T1_Aug located
#
#  T1_Aug redshift file imported
#
# --- Target Redshift: 2.5 ---
# Snapshot Number Selected: 155
# Snapshot True Redshift: 2.493534772398338
# Redshift Difference: 0.2586091040664762%
#
# Snapshot 155 gmet Raw Data Incomplete
# Using default directory: /cosma8/data/dp004/lyra/original_sample/
#
# Directory for T1_Aug located
# T1_Aug Redshift File Located
#
#  T1_Aug redshift file imported
#
# --- Target Redshift: 2.5 ---
# Snapshot Number Selected: 155
# Snapshot True Redshift: 2.493534772398338
# Redshift Difference: 0.2586091040664762%
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
# No Directory Detected for T1_Aug Snapshot 155
# T1_Aug Snapshot 155 Directory Created
#
# No T1_Aug Snapshot 155 subfind directory detected
# Subfind directory for T1_Aug Snapshot 155 created
#
# Importing T1_Aug Snapshot 155 Subfind Data
# Subfind Data imported
#
# No Subfind FoF Data Located\Loading subfind data for T1_Aug from Snapshot 155
# Subfind FoF position data saved
# Subfind FoF mass data saved
# Subfind Halo Parameters Saved
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
#
# Subfind Position Data Imported
# Subfind Mass Data Imported
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
# No T1_Aug raw Snapshot 155 data directory detected
# Directory for T1_Aug raw Snapshot 155 data created
#
# T1_Aug Snapshot 155 Gas raw data incomplete
# Importing Snapshot 155 Gas data
# T1_Aug Snapshot 155 Gas data loaded
#
# Saving required Gas snapshot data to external file
#
# Gas pos data loaded
# Gas pos data saved externally
#
# Gas mass data loaded
# Gas mass data saved externally
#
# Gas gz data loaded
# Gas gz data saved externally
#
# Gas gmet data loaded
# Gas gmet data saved externally
#
# Gas nh data loaded
# Gas nh data saved externally
#
# T1_Aug Snapshot 155 DM raw data incomplete
# Importing Snapshot 155 DM data
# T1_Aug Snapshot 155 DM data loaded
#
# Saving required DM snapshot data to external file
#
# DM pos data loaded
# DM pos data saved externally
#
# DM Mass Parameters data loaded
# DM Mass Parameters data saved externally
#
# DM mass data calculated
# DM mass data saved externally
#
# T1_Aug Snapshot 155 Stars raw data incomplete
# Importing Snapshot 155 Stars data
# T1_Aug Snapshot 155 Stars data loaded
#
# Saving required Stars snapshot data to external file
#
# Stars pos data loaded
# Stars pos data saved externally
#
# Stars mass data loaded
# Stars mass data saved externally
#
# T1_Aug Snapshot 155 Raw Data Import Complete
#
# Snapshot 155 mass raw data located
#
# Snapshot 155 nh raw data located
#
# Snapshot 155 gz raw data located
#
# Directory for T1_Aug located
#
#  T1_Aug redshift file imported
#
# --- Target Redshift: 2.5 ---
# Snapshot Number Selected: 155
# Snapshot True Redshift: 2.493534772398338
# Redshift Difference: 0.2586091040664762%
#
# Snapshot 155 Gas raw data located
#
# Snapshot 155 DM raw data located
#
# Snapshot 155 Stars raw data located
# Gas Relative Position Data Not Found, Generating
# Gas Relative Position File Generated
# DM Relative Position Data Not Found, Generating
# DM Relative Position File Generated
# Stars Relative Position Data Not Found, Generating
# Stars Relative Position File Generated
# Gas Radial Position Data Not Found, Generating
# Gas Radial Position File Generated
# DM Radial Position Data Not Found, Generating
# DM Radial Position File Generated
# Stars Radial Position Data Not Found, Generating
# Stars Radial Position File Generated
#
# gas spatial extent calculated
#
# gas bin widths calculated
#
# gas xy binned masses calculated
#
# gas xy projected densities calculated
#
# gas xz binned masses calculated
#
# gas xz projected densities calculated
#
# gas yz binned masses calculated
#
# gas yz projected densities calculated
#
# gas projected density file created
#
# dm spatial extent calculated
#
# dm bin widths calculated
#
# dm xy binned masses calculated
#
# dm xy projected densities calculated
#
# dm xz binned masses calculated
#
# dm xz projected densities calculated
#
# dm yz binned masses calculated
#
# dm yz projected densities calculated
#
# dm projected density file created
#
# stars spatial extent calculated
#
# stars bin widths calculated
#
# stars xy binned masses calculated
#
# stars xy projected densities calculated
#
# stars xz binned masses calculated
#
# stars xz projected densities calculated
#
# stars yz binned masses calculated
#
# stars yz projected densities calculated
#
# stars projected density file created
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
# /cosma/home/durham/dc-coll7/masters/plot_generation.py:163: RuntimeWarning: divide by zero encountered in log10
#   imshows=[ax_masshist[row_index][planes[plane]['index']].imshow(np.log10(loaded_data[plane]),extent=plot_extents[plane],vmin=vmin,vmax=vmax,cmap=type_plot_info[matter_type]['cmap'],aspect='equal') for plane in planes]
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
# Spatial extent calculated
#
# Bin widths calculated
#
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
# /cosma/home/durham/dc-coll7/masters/plot_generation.py:267: RuntimeWarning: divide by zero encountered in log10
#   imshows=[ax_gashist[row_index][planes[plane]['index']].imshow(np.log10(loaded_data[plane]),extent=plot_extents[plane],vmin=vmin,vmax=vmax,cmap=dens_plot_info[density]['cmap'],aspect='equal') for plane in planes]
# /cosma/home/durham/dc-coll7/masters/data_handling.py:504: RuntimeWarning: invalid value encountered in divide
#   weighted_mean_metallicity=np.divide(weighted_metallicity,bin_masses)
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
# /cosma/home/durham/dc-coll7/masters/data_handling.py:529: RuntimeWarning: divide by zero encountered in log10
#   masks={'DLA':np.log10(nH_col) >20.3,'subDLA': (20.3>np.log10(nH_col)) & (np.log10(nH_col) >19),'LymanLimit': (19>np.log10(nH_col)) & (np.log10(nH_col) >17.2)}
#  Redshift file for T1_Aug located
#
# Snapshot Number: 155
# Snapshot Redshift: 2.493534772398338
# /cosma/home/durham/dc-coll7/masters/plot_generation.py:421: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim([0,np.float64(10**5)])
# /cosma/home/durham/dc-coll7/masters/plot_generation.py:447: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   ax_gzhist.set_xlim([0,np.float64(3*10**4)])
