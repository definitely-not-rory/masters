# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
import npy_data_readers as read_npy
import halo_readers as read_halo

# %%
redshifts=np.load(f'halos/T1_Aug/area_fracs/512px/redshifts.npy')
dla=np.load(f'halos/T1_Aug/area_fracs/512px/DLA.npy')
mask=dla[:]>0
print(redshifts[mask])
# Out:
# [4.00794511 3.34435087 2.85904051 2.49353477 2.20792547 1.95965638
#  1.76969394 1.59192404 1.44865952 1.31331373 1.19582887 1.09421019
#  0.99729423]
# [[7.28607178e-04 4.92095947e-04 1.33895874e-03 1.56402588e-04
#   9.99450684e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [1.65176392e-03 6.71386719e-04 9.26971436e-04 2.09808350e-04
#   7.97271729e-04 0.00000000e+00 3.81469727e-06 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]
#  [8.35418701e-04 1.75476074e-04 9.26971436e-04 1.44958496e-04
#   8.73565674e-04 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00]]
