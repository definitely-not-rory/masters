# %%
# %load_ext autoreload 
# %autoreload 2
#^^^ Above forces Jupyter to reload all imported .py files ^^^ 

from imports import * #Imports all modules and packages (mostly used when developing in this file, will probably delete line once everything is functionalised)

#Import necessary functions
import data_handling as data
import plot_generation as plot
import npy_data_readers as read_npy
import halo_readers as read_halo

# %%
data.get_gas_only_data('halo8',redshift=0,all_plots=True,save_dir='home')
# Out:
# Directory for halo8 located
#
#  halo8 redshift file imported
#
# --- Target Redshift: 0 ---
# Snapshot Number Selected: 125
# Snapshot True Redshift: 2.220446049250313e-16
# Redshift Difference: inf%
#
# Snapshot 125 gmet Raw Data Incomplete
# Getting raw data with plots
# Using default directory: /cosma8/data/dp004/lyra/original_sample/
#
# Directory for halo8 located
# halo8 Redshift File Located
#
# Snapshot Number 125 Provided
#
#  Redshift file for halo8 located
#
# Snapshot Number: 125
# Snapshot Redshift: 2.220446049250313e-16
# /cosma/home/durham/dc-coll7/masters/halo_readers.py:84: RuntimeWarning: divide by zero encountered in scalar divide
#   print(f'\n--- Target Redshift: {target_redshift} ---\nSnapshot Number Selected: {snap_num}\nSnapshot True Redshift: {snap_redshift}\nRedshift Difference: {np.abs(snap_redshift-np.float64(target_redshift))/np.float64(target_redshift)*100}%') #Print % error on target vs snapshot redshift
# No Directory Detected for halo8 Snapshot 125
# halo8 Snapshot 125 Directory Created
#
# No halo8 Snapshot 125 subfind directory detected
# Subfind directory for halo8 Snapshot 125 created
#
# Importing halo8 Snapshot 125 Subfind Data
# Subfind Data imported
#
# No Subfind FoF Data Located\Loading subfind data for halo8 from Snapshot 125
# Subfind FoF position data saved
# Subfind FoF mass data saved
# Subfind Halo Parameters Saved
#
# No halo8 raw Snapshot 125 data directory detected
# Directory for halo8 raw Snapshot 125 data created
#
# halo8 Snapshot 125 Gas raw data incomplete
# Importing Snapshot 125 Gas data
# halo8 Snapshot 125 Gas data loaded
#
# Saving required Gas snapshot data to external file
#
# Gas pos data loaded
# Gas pos data saved externally
#
# Gas mass data loaded
# Gas mass data saved externally
#
# Gas gz data loaded
# Gas gz data saved externally
#
# Gas gmet data loaded
# Gas gmet data saved externally
#
# Gas nh data loaded
# Gas nh data saved externally
#
# halo8 Snapshot 125 DM raw data incomplete
# Importing Snapshot 125 DM data
# halo8 Snapshot 125 DM data loaded
#
# Saving required DM snapshot data to external file
#
# DM pos data loaded
# DM pos data saved externally
#
# DM Mass Parameters data loaded
# DM Mass Parameters data saved externally
#
# DM mass data calculated
# DM mass data saved externally
#
# halo8 Snapshot 125 Stars raw data incomplete
# Importing Snapshot 125 Stars data
# halo8 Snapshot 125 Stars data loaded
#
# Saving required Stars snapshot data to external file
#
# Stars pos data loaded
# Stars pos data saved externally
#
# Stars mass data loaded
# Stars mass data saved externally
#
# halo8 Snapshot 125 Raw Data Import Complete
#
# Snapshot 125 mass raw data located
#
# Snapshot 125 nh raw data located
#
# Snapshot 125 gz raw data located
#
# Directory for halo8 located
#
#  Redshift file for halo8 located
#
# Snapshot Number: 125
# Snapshot Redshift: 2.220446049250313e-16
#
# Snapshot 125 Gas raw data located
#
# Snapshot 125 DM raw data located
#
# Snapshot 125 Stars raw data located
# Gas Relative Position Data Not Found, Generating
# Gas Relative Position File Generated
# DM Relative Position Data Not Found, Generating
# DM Relative Position File Generated
# Stars Relative Position Data Not Found, Generating
# Stars Relative Position File Generated
# Gas Radial Position Data Not Found, Generating
# Gas Radial Position File Generated
# DM Radial Position Data Not Found, Generating
# DM Radial Position File Generated
# Stars Radial Position Data Not Found, Generating
# Stars Radial Position File Generated
#
# gas spatial extent calculated
#
# gas bin widths calculated
#
# gas xy binned masses calculated
#
# gas xy projected densities calculated
#
# gas xz binned masses calculated
#
# gas xz projected densities calculated
#
# gas yz binned masses calculated
#
# gas yz projected densities calculated
#
# gas projected density file created
#
# dm spatial extent calculated
#
# dm bin widths calculated
#
# dm xy binned masses calculated
#
# dm xy projected densities calculated
#
# dm xz binned masses calculated
#
# dm xz projected densities calculated
#
# dm yz binned masses calculated
#
# dm yz projected densities calculated
#
# dm projected density file created
#
# stars spatial extent calculated
#
# stars bin widths calculated
#
# stars xy binned masses calculated
#
# stars xy projected densities calculated
#
# stars xz binned masses calculated
#
# stars xz projected densities calculated
#
# stars yz binned masses calculated
#
# stars yz projected densities calculated
#
# stars projected density file created
#
#  Redshift file for halo8 located
#
# Snapshot Number: 125
# Snapshot Redshift: 2.220446049250313e-16
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data.get_gas_only_data('halo8',redshift=0,all_plots=True,save_dir='home')
#
# File ~/masters/data_handling.py:477, in get_gas_only_data(halo, **kwargs)
#     475 if 'all_plots' in kwargs: #Checks if override for all plots is enabled
#     476         if kwargs['all_plots']==True:
# --> 477             get_mass_density_data(halo,bin_num=bin_num,snap_num=snap_num,all_plots=True,save_dir=save_dir)
#     478 else:
#     479     get_mass_density_data(halo,bin_num=bin_num,snap_num=snap_num,save_dir=save_dir)
#
# File ~/masters/data_handling.py:383, in get_mass_density_data(halo, **kwargs)
#     381         if os.path.isdir(f'figures/{halo}/{bin_num}/proj_mass_density')!=True:
#     382             os.makedirs(f'figures/{halo}/{bin_num}/proj_mass_density',exist_ok=True)
# --> 383         plot.proj_mass_density(halo,bin_num,snap_num=snap_num)
#     385 if os.path.isdir(f'/cosma/{save_dir}/durham/dc-coll7/halos/{halo}/{snap_num}/binned/radial_mass_density')!=True:
#     386     os.mkdir(f'/cosma/{save_dir}/durham/dc-coll7/halos/{halo}/{snap_num}/binned/radial_mass_density')
#
# File ~/masters/plot_generation.py:160, in proj_mass_density(halo, bin_num, **kwargs)
#     157 planes={'xy':{'index':0,'axes':['x','y'],'x_label':'$x$ ($kpc$)','y_label':'$y$ ($kpc$)'},'xz':{'index':1,'axes':['x','z'],'x_label':'$x$ ($kpc$)','y_label':'$z$ ($kpc$)'},'yz':{'index':2,'axes':['y','z'],'x_label':'$y$ ($kpc$)','y_label':'$z$ ($kpc$)'}}
#     159 for matter_type in req_types:
# --> 160     loaded_data={f'{plane}':np.load(f'/cosma/apps/durham/dc-coll7/halos/{halo}/{snap_num}/binned/{bin_num}px/total_mass/{matter_type}.npy')[planes[plane]['index']]for plane in planes}
#     161     loaded_data['rel_pos']=read_raw_file(halo,matter_type,'rel_pos',snap_num=snap_num)
#     163     print(matter_type)
#
# File ~/masters/plot_generation.py:160, in <dictcomp>(.0)
#     157 planes={'xy':{'index':0,'axes':['x','y'],'x_label':'$x$ ($kpc$)','y_label':'$y$ ($kpc$)'},'xz':{'index':1,'axes':['x','z'],'x_label':'$x$ ($kpc$)','y_label':'$z$ ($kpc$)'},'yz':{'index':2,'axes':['y','z'],'x_label':'$y$ ($kpc$)','y_label':'$z$ ($kpc$)'}}
#     159 for matter_type in req_types:
# --> 160     loaded_data={f'{plane}':np.load(f'/cosma/apps/durham/dc-coll7/halos/{halo}/{snap_num}/binned/{bin_num}px/total_mass/{matter_type}.npy')[planes[plane]['index']]for plane in planes}
#     161     loaded_data['rel_pos']=read_raw_file(halo,matter_type,'rel_pos',snap_num=snap_num)
#     163     print(matter_type)
#
# File /cosma/apps/durham/dc-coll7/venvs/rjscmasters/lib/python3.9/site-packages/numpy/lib/npyio.py:427, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     425     own_fid = False
#     426 else:
# --> 427     fid = stack.enter_context(open(os_fspath(file), "rb"))
#     428     own_fid = True
#     430 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: '/cosma/apps/durham/dc-coll7/halos/halo8/125/binned/512px/total_mass/gas.npy'
